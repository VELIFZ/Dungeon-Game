# %% [markdown]
# ### Dungeon Egg Hunt
#
# Using object-oriented programming principles, create an egg hunt game. Your objective is to go through the dungeon to collect the basket and the eggs. Once you've retrieved all of the items, exit through the door.
#
# **RULES**:
#
# `1. ` Player, Monster, Door, Basket and the 3 Eggs must all start at a random locations on a grid.
#
# `2. ` Player must collect the Basket first before collecting the 3 Eggs. Player will not be able to collect any Eggs until it first has collected the Basket.
#
# `3. ` Once Player collects the Basket, then and only then will it be able to collect any Eggs.
#
# `4. ` When Player collects the Basket and the 3 Eggs, Player will need to head toward the Door.
#
# `5. ` The entire time the Player is searching for the Eggs, Basket and the Door, there will be a Monster trying to eat the Player.
#
# `6. ` If the Monster lands on the same space as the Player, or the Player lands on the same space as the Monster, the game ends and the game will prompt the user to play again.
#
# `7. ` If Player reaches the Door before the Monster catches them, you win the game and the game will prompt the user to play again.
#
# `8. ` The Player does not know where any of the other tokens are, so all of the tokens with the exception of the Player will be hidden.
#
# **Note**: For debugging purposes, you can create tokens for each of the other tokens. For example:<br>
# * Player (P)
# * Monster (M)
# * Eggs (O)
# * Basket (U)
# * Door (D)

# %%
import random
from IPython.display import clear_output

class Game():
    def __init__(self):
        self.cells = [
            (0,0),(1,0),(2,0),(3,0),(4,0),
            (0,1),(1,1),(2,1),(3,1),(4,1),
            (0,2),(1,2),(2,2),(3,2),(4,2),
            (0,3),(1,3),(2,3),(3,3),(4,3),
            (0,4),(1,4),(2,4),(3,4),(4,4),
          ]
        self.position = random.choice(random.choice(self.cells))
        #self.display = [ ]
        self.player = 
        self.monster = 
        self.door = 
        self.basket = []
        self.eggs = [] 
        
    def drawMap(self):
        # Turn the tuples to lists
        self.cells = [list(index) for index in self.cells]
        # Print [P] for player's position - should I get it from random_positions?
        for i in range(len(self.cells)):
            #if self.cells[i][0] == self.player.position or self.cells[i][1] == self.player.position:
            if self.cells[i] == self.cells[self.p_position]:
                self.cells[i] = ['P']
            else:
                self.cells[i] = [ ] 
        # Make 5 rows and 5 columns from index items
        for index, item in enumerate(self.cells):
            if (index + 1) % 5 == 0:
                print(item)
            else:
                print(item, end=" ")
        
    def rules(self):
        
    player_class.move_p()
    monster_class.move_m()
    eggs_class.collect_eggs()
    
        while True:
            players_hand = [] 
            if self.cells[self.p_position] == self.cells[self.m_position]:
                print("Game Over!")
                break
            elif self.cells[self.p_position] == self.cells[self.b_position]:
                players_hand.append(self.basket)
                print('You got the basket, now go get the eggs!')
                self.cells.remove(self.basket) # do I need this?
            elif self.cells[self.p_position] == self.cells[self.e_position]:
                if self.basket in players_hand:
                    players_hand.append(self.eggs)# do I need another for or while loop here
                    #print('You got {one} egg') - another print after the loop that tells p got the all eggs
                    self.cells.pop(self.eggs)
                else:
                    continue
            elif self.cells[self.p_position] == self.cells[self.d_position]:
                if self.basket not in players_hand and self.eggs not in players_hand:
                    continue
                else:
                    self.cells[self.d_position] = ['/']
                    print('You Won!')
                    break

                                                   
# class Token:
#     def __init__(self, cells):
#         # Not sure if I need this
#         self.display = [ ]
#         # Assigning all the tokens to random indexes in the nested list
#         self.position = random.choice(random.choice(self.cells))
        
class Player:
    
    def __init__(self):
        #super().__init__(player)
        #self.player = player
        self.p_position = self.position
        self.inner_list_index = self.cells.index(self.cells[self.p_position])                                           
        
        
    def move_p(self):
        ask = input("Enter 'W' for up, 'S' for down, 'A' for left, or 'D' for right: \n").upper()
        clear_output()                                           
        if ask == 'W':
            if self.inner_list_index > 4:
                self.cells[self.inner_list_index - 5] = ['P']
        elif ask == 'S':
            if self.inner_list_index < 20:
                self.cells[self.inner_list_index + 5] = ['P']
        elif ask == 'A':
            self.cells[self.inner_list_index - 1] = ['P']
        elif ask == 'D':
            self.cells[self.inner_list_index + 1] = ['P']
        else:
            print("Not recognized, please try again")

class Monster:
    def __init__(self, monster):
#         super().__init__(monster)
#         self.monster = monster                                                   
        self.m_position = self.position

        
    def move_m(self):
        pass

class Egg:
    def __init__(self, eggs):
#         super().__init__(eggs)
#         self.eggs = []                                     
        self.e_position = self.position

    def collect_eggs(self): # can't think how can I adapt this function to this project
        egg = 0
        while egg < 3:
            self.eggs.append(egg)
            egg +=1                                                                                          

class Basket:
    def __init__(self, basket):
#         super().__init__(basket)
#         self.basket = []                                                   
        self.b_position = self.position
       
class Door:
    def __init__(self, door):
#         super().__init__(door)
#         self.door = door                                                   
        self.d_position = self.position

player_class = Player()
monster_class = Monster()                                                   
eggs_class = Eggs()
                                                   
game = Game()
game.rules()
# Out:
#   File "<ipython-input-196-05f59aaaa443>", line 15
#     self.player =
#                   ^
# SyntaxError: invalid syntax

# %%
import random
from IPython.display import clear_output

class Game():
    def __init__(self):
        self.cells = [
            (0,0),(1,0),(2,0),(3,0),(4,0),
            (0,1),(1,1),(2,1),(3,1),(4,1),
            (0,2),(1,2),(2,2),(3,2),(4,2),
            (0,3),(1,3),(2,3),(3,3),(4,3),
            (0,4),(1,4),(2,4),(3,4),(4,4),
          ]
        self.position = random.choice(random.choice(self.cells))
        self.p_position = self.position
        self.inner_list_index = self.cells.index(self.cells[self.p_position])
        self.b_position = self.position
        self.d_position = self.position
        self.display = [ ]
        self.player = 0
        self.monster = 0
        self.door = 0
        self.basket = []
        self.eggs = [] 
        
    def drawMap(self):
        # Turn the tuples to lists
        self.cells = [list(index) for index in self.cells]
        # Print [P] for player's position - should I get it from random_positions?
        for i in range(len(self.cells)):
            #if self.cells[i][0] == self.player.position or self.cells[i][1] == self.player.position:
            if self.cells[i] == self.cells[self.p_position]:
                self.cells[i] = ['P']
            else:
                self.cells[i] = [ ] 
        # Make 5 rows and 5 columns from index items
        for index, item in enumerate(self.cells):
            if (index + 1) % 5 == 0:
                print(item)
            else:
                print(item, end=" ")
        
    def rules(self):
        move_p()
        move_m()
        collect_eggs()
    
        while True:
            players_hand = []
            if self.cells[self.p_position] == self.cells[self.m_position]:
                print("Game Over!")
                break
            elif self.cells[self.p_position] == self.cells[self.b_position]:
                players_hand.append(self.basket)
                print('You got the basket, now go get the eggs!')
                self.cells.remove(self.basket) # do I need this?
            elif self.cells[self.p_position] == self.cells[self.e_position]:
                if self.basket in players_hand:
                    players_hand.append(self.eggs)# do I need another for or while loop here
                    #print('You got {one} egg') - another print after the loop that tells p got the all eggs
                    self.cells.pop(self.eggs)
                else:
                    continue
            elif self.cells[self.p_position] == self.cells[self.d_position]:
                if self.basket not in players_hand and self.eggs not in players_hand:
                    continue
                else:
                    self.cells[self.d_position] = ['/']
                    print('You Won!')
                    break

   
    def move_p(self):
        ask = input("Enter 'W' for up, 'S' for down, 'A' for left, or 'D' for right: \n").upper()
        clear_output()                                           
        if ask == 'W':
            if self.inner_list_index > 4:
                self.cells[self.inner_list_index - 5] = ['P']
        elif ask == 'S':
            if self.inner_list_index < 20:
                self.cells[self.inner_list_index + 5] = ['P']
        elif ask == 'A':
            self.cells[self.inner_list_index - 1] = ['P']
        elif ask == 'D':
            self.cells[self.inner_list_index + 1] = ['P']
        else:
            print("Not recognized, please try again")
    
    def move_m(self):
        self.m_position = self.position
        pass

    def collect_eggs(self): # can't think how can I adapt this function to this project
        self.e_position = self.position
        egg = 0
        while egg < 3:
            self.eggs.append(egg)
            egg +=1                                                                                          
                                                   
game = Game()
game.rules()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-201-47ee11d791d0> in <module>
#      98
#      99 game = Game()
# --> 100 game.rules()
#
# <ipython-input-201-47ee11d791d0> in rules(self)
#      41
#      42     def rules(self):
# ---> 43         move_p()
#      44         move_m()
#      45         collect_eggs()
#
# NameError: name 'move_p' is not defined

# %%
def drawMap():
    
    cells = [
    (0,0),(1,0),(2,0),(3,0),(4,0),
    (0,1),(1,1),(2,1),(3,1),(4,1),
    (0,2),(1,2),(2,2),(3,2),(4,2),
    (0,3),(1,3),(2,3),(3,3),(4,3),
    (0,4),(1,4),(2,4),(3,4),(4,4)]
    
    cells = [list(index) for index in cells]
    
    position = random.choice(random.choice(cells))
    k = random.choice(random.choice(cells))
    print(k)
    print(cells[k])
    print(position)
    print(cells[position])
    print(f'This is index number of {position} => {cells[position].index(position)}')
    #random_positions_lists = random.sample(cells, 7) # this is list of tuples

    for i in range(len(cells)):
        
        if cells[i] == cells[position]:
            cells[i] = ['P']
        elif cells[position] == cells[k]:
            cells[i] = ['dead']
        else:
            cells[i] = [' ']
    for index, item in enumerate(cells):
        if (index + 1) % 5 == 0:
            print(item)
            
        else:
            print(item, end = " ")

drawMap()
# Out:
# 0
# [0, 0]
# 0
# [0, 0]
# This is index number of 0 => 0
# ['P'] ['dead'] ['dead'] ['dead'] ['dead']
# ['dead'] ['dead'] ['dead'] ['dead'] ['dead']
# ['dead'] ['dead'] ['dead'] ['dead'] ['dead']
# ['dead'] ['dead'] ['dead'] ['dead'] ['dead']
# ['dead'] ['dead'] ['dead'] ['dead'] ['dead']

# %%
def drawMap():
    
    cells = [
    (0,0),(1,0),(2,0),(3,0),(4,0),
    (0,1),(1,1),(2,1),(3,1),(4,1),
    (0,2),(1,2),(2,2),(3,2),(4,2),
    (0,3),(1,3),(2,3),(3,3),(4,3),
    (0,4),(1,4),(2,4),(3,4),(4,4)]
    
    cells = [list(index) for index in cells]
    
    p_position = random.choice(random.choice(cells))
    m_position = random.choice(random.choice(cells))
    print(m_position)
    print(cells[m_position])
    print(p_position)
    print(f"Player'in oldugu yerin degeri = {p_position}")
    print(cells[p_position])
    print(f'This is index number of {p_position} => {cells[p_position].index(p_position)}')
    #random_positions_lists = random.sample(cells, 7) # this is list of tuples

    for i in range(len(cells)):
        
        if cells[i] == cells[p_position]:
            cells[i] = ['P']
        elif cells[p_position] == cells[m_position]:
            cells[p_position] = ['dead']
        else:
            cells[i] = [' ']
    for index, item in enumerate(cells):
        if (index + 1) % 5 == 0:
            print(item)
            
        else:
            print(item, end = " ")

drawMap()
# Out:
# 4
# [4, 0]
# 4
# [4, 0]
# This is index number of 4 => 0
# [0, 0] [1, 0] [2, 0] [3, 0] ['dead']
# [0, 1] [1, 1] [2, 1] [3, 1] [4, 1]
# [0, 2] [1, 2] [2, 2] [3, 2] [4, 2]
# [0, 3] [1, 3] [2, 3] [3, 3] [4, 3]
# [0, 4] [1, 4] [2, 4] [3, 4] [4, 4]

# %%
def drawMap():
    
    cells = [
    (0,0),(1,0),(2,0),(3,0),(4,0),
    (0,1),(1,1),(2,1),(3,1),(4,1),
    (0,2),(1,2),(2,2),(3,2),(4,2),
    (0,3),(1,3),(2,3),(3,3),(4,3),
    (0,4),(1,4),(2,4),(3,4),(4,4)]
    
    cells = [list(index) for index in cells]
    
    p_position = random.choice(random.choice(cells))
    input_index = cells.index(cells[p_position])
    print(input_index)
    print(f' bir arttirilmis hali = {input_index +1}')
    
    for i in range(len(cells)):
        if cells[i] == cells[p_position]:
            cells[p_position] = ['P']
            #cells[input_index-5] = ['P']
        else:
            cells[i] = [' ']
    for index, item in enumerate(cells):
        if (index + 1) % 5 == 0:
            print(item)   
        else:
            print(item, end = " ")
         
    ask = input("Enter 'W' for up, 'S' for down, 'A' for left, or 'D' for right: \n").upper()
    if ask == 'W':
        if input_index > 4:
            cells[input_index-5] = ['P']
    elif ask == 'S':
        if input_index < 20:
            cells[input_index+5] = ['P']
    elif ask == 'A':
        cells[input_index-1] = ['P']
    elif ask == 'D':
        cells[input_index+1] = ['P']
    else:
        print("Not recognized, please try again")
        

drawMap()
# Out:
# 1
#  bir arttirilmis hali = 2
# [' '] ['P'] [' '] [' '] [' ']
# [' '] [' '] [' '] [' '] [' ']
# [' '] [' '] [' '] [' '] [' ']
# [' '] [' '] [' '] [' '] [' ']
# [' '] [' '] [' '] [' '] [' ']
# Enter 'W' for up, 'S' for down, 'A' for left, or 'D' for right:
# s

# %%
cells = [
    (0,0),(1,0),(2,'x'),(3,0),(4,0),
    (0,1),(1,1),(2,1),(3,1),(4,1),
    (0,2),(1,2),(2,2),(3,2),(4,2),
    (0,3),(1,3),(2,3),(3,3),(4,3),
    (0,4),(1,4),(2,4),(3,4),(4,4)]

cells = [list(index) for index in cells]

cells2 = [print(item) if (index + 1) % 5 == 0 else print(item, end = " ") for index, item in enumerate(cells)]

print(cells2)
# Out:
# [0, 0] [1, 0] [2, 'x'] [3, 0] [4, 0]
# [0, 1] [1, 1] [2, 1] [3, 1] [4, 1]
# [0, 2] [1, 2] [2, 2] [3, 2] [4, 2]
# [0, 3] [1, 3] [2, 3] [3, 3] [4, 3]
# [0, 4] [1, 4] [2, 4] [3, 4] [4, 4]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
